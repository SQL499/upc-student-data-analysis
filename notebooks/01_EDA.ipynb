# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Cargar datos

# %%
df = pd.read_csv('../data/raw/upc_alumnos.csv')

# %% [markdown]
# # Primer vistazo

# %%
print(df.head())
print(df.info())
# Out:
#        codigo             nombres apellido_paterno apellido_materno  \
# 0  u202222893         NAOMY HARET         PARRILLA           QUISPE
# 1  u202217816        MIGUEL ANGEL           PORRAS            AVILA
# 2  u202214426  CERAYDDEE MILAGROS           TORRES           FLORES
# 3  u202224710    ICHELLE MILAGROS          MURILLO            MONGE
# 4  u202222000         JESUS ANDRE           RONDON            BRAVO
#
#       numero                           correo   correo_universitario
# 0  931444131           nanami.hanap@gmail.com  u202222893@upc.edu.pe
# 1  912844336         MIGUEL.PA123@HOTMAIL.COM  u202217816@upc.edu.pe
# 2  963450104  cerayddeetorresflores@gmail.com  u202214426@upc.edu.pe
# 3  933908148            ichelle2509@gmail.com  u202224710@upc.edu.pe
# 4  922302025           jesusgam5r11@gmail.com  u202222000@upc.edu.pe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72935 entries, 0 to 72934
# Data columns (total 7 columns):
# ...

# %% [markdown]
# # Verificar valores nulos

# %%
print(df.isnull().sum())
# Out:
# codigo                    0
# nombres                   0
# apellido_paterno          0
# apellido_materno        208
# numero                  885
# correo                   65
# correo_universitario      0
# dtype: int64

# %% [markdown]
# # Análisis de columnas clave

# %%
print(df['correo'].str.contains('@upc.edu.pe').value_counts())
# Out:
# correo
# False    71514
# True      1356
# Name: count, dtype: int64

# %% [markdown]
# # Visualización simple

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['codigo'].str[0:5], bins=20)
plt.title("Distribución por cohorte (aproximada)")
# Out:
# Text(0.5, 1.0, 'Distribución por cohorte (aproximada)')
